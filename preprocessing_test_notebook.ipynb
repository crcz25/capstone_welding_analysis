# %%
import numpy as np
import pandas as pd
import seaborn as sns
from scipy.ndimage import median_filter, gaussian_filter, uniform_filter1d

# %%
data = np.load("../capstone_welding_analysis/ros2_ws/ranges_29-11-2023-14-44-13.npy")
first_batch = data[1].copy()
first_row = first_batch[0].copy()

# %%
np.set_printoptions(threshold=np.inf)

# %%
window_size = 1
first_row = np.where(first_row==0, np.nan, first_row)
first_row = pd.Series(first_row)
data_filtered = first_row.interpolate()
data_filtered = gaussian_filter(data_filtered, sigma=10, mode='nearest')
plot = sns.lineplot(data_filtered)
plot.set_ylim(0, 70)
# Out:
# (0.0, 70.0)
